# %%
import matplotlib.pyplot as plt
from common import mlbench as ml

# %% [markdown]
# # mlbench

# %%
X,y = ml.twoDnormals(100, cl=2, sd=1)                # 混合正規分布
plt.scatter(X[y==0,0],X[y==0,1],marker='+',s=100)
plt.scatter(X[y==1,0],X[y==1,1],marker='.',s=100)
plt.show()

# %%
X,y = ml.spirals(300, cycles=2, sd=0.05)             # スパイラル
plt.scatter(X[y==0,0],X[y==0,1],marker='+',s=100)
plt.scatter(X[y==1,0],X[y==1,1],marker='.',s=100)
plt.show()

# %%
from sklearn import datasets       # datasets を使う
iris = datasets.load_iris()        # irisデータを利用
# 大きなデータセットはダウンロード
#  ~/scikit_learn_data/ に保存
_20newsgroups = datasets.fetch_20newsgroups()

# %% [markdown]
# # datasets

# %%
d = datasets.make_circles()                           # データを生成
plt.scatter(d[0][:,0],d[0][:,1],c=d[1])
plt.show()
